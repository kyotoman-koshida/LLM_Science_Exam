# %% [markdown]
# # <center style="font-family: consolas; font-size: 32px; font-weight: bold;"> Kaggle - LLM Science Exam</center>
# <p><center style="color:#949494; font-family: consolas; font-size: 20px;">Use LLMs to answer difficult science questions</center></p>
#
# ***

# %% [markdown]
# # <center style="font-family: consolas; font-size: 32px; font-weight: bold;">(ಠಿ⁠_⁠ಠ) Overview</center>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The goal of the competition is to answer difficult science-based questions written by a Large Language Model (LLM).</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The competition aims to help researchers understand the ability of LLMs to test themselves and explore the potential of LLMs that can be run in resource-constrained environments.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The scope of large language model capabilities is expanding, and researchers are using LLMs to characterize themselves.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ Many existing natural language processing benchmarks have become trivial for state-of-the-art models, so there is a need to create more challenging tasks to test increasingly powerful models.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The dataset for the competition was generated by providing snippets of text on various scientific topics to the gpt3.5 model and asking it to write multiple choice questions (with known answers). Easy questions were filtered out.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ Sign language recognition AI for text entry lags far behind voice-to-text or even gesture-based typing, as robust datasets didn't previously exist.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The largest models currently run on Kaggle have around 10 billion parameters, while gpt3.5 has 175 billion parameters.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The competition aims to explore whether a question-answering model more than 10 times smaller than gpt3.5 can effectively answer questions written by gpt3.5. The results will shed light on the benchmarking and self-testing capabilities of LLMs.</p>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">🔴 Description and implementation of the data collection algorithm is described in the second section of this notebook.</p>
#
# <p style="font-family: consolas; font-size: 16px;">🔴 An implementation of this approach on the deberta-v3-large model can be found in this notebook -- <a href="https://www.kaggle.com/code/leonidkulyk/lb-0-709-llm-se-deberta-v3-large-i-1k-wiki"><strong>[LB: 0.709] LLM-SE ~ deberta-v3-large -i | 1k Wiki</strong></a>. Training notebook with weights and logs -- <a href="https://www.kaggle.com/code/leonidkulyk/lb-0-709-llm-se-deberta-v3-large-t-1k-wiki"><strong>[LB: 0.709] LLM-SE ~ deberta-v3-large -t | 1k Wiki</strong></a>.</p>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">🔴 UPDATE (see previous versions):</p>
#
# - <p style="font-family: consolas; font-size: 16px;">More accurate selection of STEM categories.</p>
# - <p style="font-family: consolas; font-size: 16px;">Randomizing STEM topics with a emphasis on "S".</p>

# %% [markdown]
# #### <a id="top"></a>
# # <div style="box-shadow: rgb(60, 121, 245) 0px 0px 0px 3px inset, rgb(255, 255, 255) 10px -10px 0px -3px, rgb(31, 193, 27) 10px -10px, rgb(255, 255, 255) 20px -20px 0px -3px, rgb(255, 217, 19) 20px -20px, rgb(255, 255, 255) 30px -30px 0px -3px, rgb(255, 156, 85) 30px -30px, rgb(255, 255, 255) 40px -40px 0px -3px, rgb(255, 85, 85) 40px -40px; padding:20px; margin-right: 40px; font-size:30px; font-family: consolas; text-align:center; display:fill; border-radius:15px; color:rgb(60, 121, 245);"><b>Table of contents</b></div>
#
# <div style="background-color: rgba(60, 121, 245, 0.03); padding:30px; font-size:15px; font-family: consolas;">
# <ul>
#     <li><a href="#0" target="_self" rel=" noreferrer nofollow">0. Import all dependencies</a></li>
#     <li><a href="#1" target="_self" rel=" noreferrer nofollow">1. Data overview</a>
#         <ul>
#             <li><a href="#1.1" target="_self" rel=" noreferrer nofollow">1.1 train.csv</a></li>
#             <li><a href="#1.2" target="_self" rel=" noreferrer nofollow">1.2 test.csv</a></li>
#         </ul>
#     </li>
#     <li><a href="#2" target="_self" rel=" noreferrer nofollow">2. Data gathering</a>
#         <ul>
#             <li><a href="#2.1" target="_self" rel=" noreferrer nofollow">2.1 Form a list of STEM topics</a></li>
#             <li><a href="#2.2" target="_self" rel=" noreferrer nofollow">2.2 Randomly select a category or a page</a></li>
#             <li><a href="#2.3" target="_self" rel=" noreferrer nofollow">2.3 Extract the text from selected page</a></li>
#             <li><a href="#2.4" target="_self" rel=" noreferrer nofollow">2.4 Compose a message to the LLM model</a></li>
#             <li><a href="#2.5" target="_self" rel=" noreferrer nofollow">2.5 Сombine all elements of the pipeline</a></li>
#         </ul>
#     </li>
#     <li><a href="#3" target="_self" rel=" noreferrer nofollow">3. Data gathering enhancements</a></li>
# </ul>
#
# </div>

# %% [markdown]
# <a id="0"></a>
# # <div style="box-shadow: rgba(0, 0, 0, 0.16) 0px 1px 4px inset, rgb(51, 51, 51) 0px 0px 0px 3px inset; padding:20px; font-size:32px; font-family: consolas; text-align:center; display:fill; border-radius:15px;  color:rgb(34, 34, 34);"> <b> 0. Import all dependencies </b></div>

# %%
# !pip install openai itables Wikipedia-API  -q

# %%
import os
import random
import pickle
import openai
import requests
import wikipediaapi
import itables
import numpy as np
import pandas as pd
import plotly.express as px
#from kaggle_secrets import UserSecretsClient

# %%
# specify OpenAI API key in Kaggle's secrets add-ons.
# user_secrets = UserSecretsClient()
# openai.api_key = user_secrets.get_secret("openai_api")

# %%
import os
from dotenv import load_dotenv

# .envファイルを読み込む
load_dotenv()

dotenv_path = os.path.join("/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/config", '.env')
load_dotenv(dotenv_path)

openai.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# <a id="1"></a>
# # <div style="box-shadow: rgba(0, 0, 0, 0.16) 0px 1px 4px inset, rgb(51, 51, 51) 0px 0px 0px 3px inset; padding:20px; font-size:32px; font-family: consolas; text-align:center; display:fill; border-radius:15px;  color:rgb(34, 34, 34);"> <b> 1. Data overview</b></div>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ The dataset for this competition consists of multiple-choice questions generated by a Large Language Model (LLM).</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The questions are accompanied by options labeled A, B, C, D, and E, and each question has a correct answer labeled "answer".</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The goal is to predict the top three most probable answers given a question prompt. </p>

# %% [markdown]
# <a id="1.1"></a>
# ## <div style="box-shadow: rgba(0, 0, 0, 0.18) 0px 2px 4px inset; padding:20px; font-size:24px; font-family: consolas; text-align:center; display:fill; border-radius:15px; color:rgb(67, 66, 66)"> <b> 1.1 train.csv</b></div>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ The train.csv file contains <b>200 questions</b> with their corresponding correct answers.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ Each question consists of a prompt (the question text) and options <b>A, B, C, D, and E</b>.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The correct answer is indicated by the <code>answer</code> column, which contains the label of the most correct answer, as defined by the generating LLM. </p>

# %%
train_df = pd.read_csv("../input/train.csv")

# %%
table = itables.show(train_df, table_options=dict(pageLength=10))
table
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="c8e4c755-94f2-4569-b417-e34181731f82" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>id</th>
#       <th>prompt</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>answer</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[0, "Which of the following statements accurately describes the impact of Modified Newtonian Dynamics (MOND) on the observed \"missing baryonic mass\" discrepancy in galaxy clusters?", "MOND is a theory that reduces the observed missing baryonic mass in galaxy clusters by postulating the existence of a new form of matter called \"fuzzy dark matter.\"", "MOND is a theory that increases the discrepancy between the observed missing baryonic mass in galaxy clusters and the measured velocity dispersions from a factor of around 10 to a factor of about 20.", "MOND is a theory that explains the missing baryonic mass in galaxy clusters that was previously considered dark matter by demonstrating that the mass is in the form of neutrinos and axions.", "MOND is a theory that reduces the discrepancy between the observed missing baryonic mass in galaxy clusters and the measured velocity dispersions from a factor of around 10 to a factor of about 2.", "MOND is a theory that eliminates the observed missing baryonic mass in galaxy clusters by imposing a new mathematical formulation of gravity that does not require the existence of dark matter.", "D"], [1, "Which of the following is an accurate definition of dynamic scaling in self-similar systems?", "Dynamic scaling refers to the evolution of self-similar systems, where data obtained from snapshots at fixed times exhibits similarity to the respective data taken from snapshots of any earlier or later time. This similarity is tested by a certain time-dependent stochastic variable x.", "Dynamic scaling refers to the non-evolution of self-similar systems, where data obtained from snapshots at fixed times is similar to the respective data taken from snapshots of any earlier or later time. This similarity is tested by a certain time-dependent stochastic variable x.", "Dynamic scaling refers to the evolution of self-similar systems, where data obtained from snapshots at fixed times is dissimilar to the respective data taken from snapshots of any earlier or later time. This dissimilarity is tested by a certain time-independent stochastic variable y.", "Dynamic scaling refers to the non-evolution of self-similar systems, where data obtained from snapshots at fixed times is dissimilar to the respective data taken from snapshots of any earlier or later time. This dissimilarity is tested by a certain time-independent stochastic variable y.", "Dynamic scaling refers to the evolution of self-similar systems, where data obtained from snapshots at fixed times is independent of the respective data taken from snapshots of any earlier or later time. This independence is tested by a certain time-dependent stochastic variable z.", "A"], [2, "Which of the following statements accurately describes the origin and significance of the triskeles symbol?", "The triskeles symbol was reconstructed as a feminine divine triad by the rulers of Syracuse, and later adopted as an emblem. Its usage may also be related to the Greek name of Sicily, Trinacria, which means \"having three headlands.\" The head of Medusa at the center of the Sicilian triskeles represents the three headlands.", "The triskeles symbol is a representation of three interlinked spirals, which was adopted as an emblem by the rulers of Syracuse. Its usage in modern flags of Sicily has its origins in the ancient Greek name for the island, Trinacria, which means \"Sicily with three corners.\" The head of Medusa at the center is a representation of the island's rich cultural heritage.", "The triskeles symbol is a representation of a triple goddess, reconstructed by the rulers of Syracuse, who adopted it as an emblem. Its significance lies in the fact that it represents the Greek name for Sicily, Trinacria, which contains the element \"tria,\" meaning three. The head of Medusa at the center of the Sicilian triskeles represents the three headlands.", "The triskeles symbol represents three interlocked spiral arms, which became an emblem for the rul ...

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ Let's display the distributions of word counts for each of the fields.</p>

# %%
fig = px.histogram([len(x.split(" ")) for x in train_df.prompt], nbins=40, color_discrete_sequence=['goldenrod'])
fig.update_layout(
    showlegend=False,
    xaxis_title="Number of words",
    title={
        'text': "Distribution of the number of words in prompts",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    }
)
fig.show()

# %%
fig = px.histogram([len(x.split(" ")) for x in train_df.A], nbins=40, color_discrete_sequence=['darkgreen'])
fig.update_layout(
    showlegend=False,
    xaxis_title="Number of words",
    title={
        'text': "Distribution of the number of words in option A",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    }
)
fig.show()

# %%
fig = px.histogram([len(x.split(" ")) for x in train_df.B], nbins=40, color_discrete_sequence=['cornflowerblue'])
fig.update_layout(
    showlegend=False,
    xaxis_title="Number of words",
    title={
        'text': "Distribution of the number of words in option B",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    }
)
fig.show()

# %%
fig = px.histogram([len(x.split(" ")) for x in train_df.C], nbins=40, color_discrete_sequence=['darkslateblue'])
fig.update_layout(
    showlegend=False,
    xaxis_title="Number of words",
    title={
        'text': "Distribution of the number of words in option C",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    }
)
fig.show()

# %%
fig = px.histogram([len(x.split(" ")) for x in train_df.D], nbins=40)
fig.update_layout(
    showlegend=False,
    xaxis_title="Number of words",
    title={
        'text': "Distribution of the number of words in option D",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    }
)
fig.show()

# %%
fig = px.histogram([len(x.split(" ")) for x in train_df.E], nbins=40, color_discrete_sequence=['darkolivegreen'])
fig.update_layout(
    showlegend=False,
    xaxis_title="Number of words",
    title={
        'text': "Distribution of the number of words in option E",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    }
)
fig.show()

# %% [markdown]
# <a id="1.2"></a>
# ## <div style="box-shadow: rgba(0, 0, 0, 0.18) 0px 2px 4px inset; padding:20px; font-size:24px; font-family: consolas; text-align:center; display:fill; border-radius:15px; color:rgb(67, 66, 66)"> <b> 1.2 test.csv</b></div>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ The test.csv file contains the test set for the competition.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ <b>The task is to predict the top <code>3</code> most probable answers</b> for each question prompt.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The format of the test set is the same as the training set, with questions, options (A, B, C, D, and E), and the prompt text.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ The test set has approximately 4,000 different prompts, which may differ in subject matter from the training set.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ <b>NOTE</b>: The test data you see here just a copy of the training data without the answers.</p>

# %%
test_df = pd.read_csv("../input/test.csv")

# %%
test_df.head()
# Out:
#    id                                             prompt  \
# 0   0  Which of the following statements accurately d...
# 1   1  Which of the following is an accurate definiti...
# 2   2  Which of the following statements accurately d...
# 3   3  What is the significance of regularization in ...
# 4   4  Which of the following statements accurately d...
#
#                                                    A  \
# 0  MOND is a theory that reduces the observed mis...
# 1  Dynamic scaling refers to the evolution of sel...
# 2  The triskeles symbol was reconstructed as a fe...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    B  \
# 0  MOND is a theory that increases the discrepanc...
# 1  Dynamic scaling refers to the non-evolution of...
# 2  The triskeles symbol is a representation of th...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    C  \
# 0  MOND is a theory that explains the missing bar...
# 1  Dynamic scaling refers to the evolution of sel...
# 2  The triskeles symbol is a representation of a ...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    D  \
# 0  MOND is a theory that reduces the discrepancy ...
# 1  Dynamic scaling refers to the non-evolution of...
# 2  The triskeles symbol represents three interloc...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    E
# 0  MOND is a theory that eliminates the observed ...
# 1  Dynamic scaling refers to the evolution of sel...
# 2  The triskeles symbol is a representation of th...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...

# %% [markdown]
# <a id="2"></a>
# # <div style="box-shadow: rgba(0, 0, 0, 0.16) 0px 1px 4px inset, rgb(51, 51, 51) 0px 0px 0px 3px inset; padding:20px; font-size:32px; font-family: consolas; text-align:center; display:fill; border-radius:15px;  color:rgb(34, 34, 34);"> <b> 2. Data gathering</b></div>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ The most important part of this competition is data collection. Therefore, it is important to understand how the test dataset was formed and how to reproduce the method of its collection.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ According to the competition description, the test dataset was formed based on pages from Wikipedia. In other words, a page on the subject of Science, Technology, Engineering, and Mathematics (with the emphasis on "S") was selected, an excerpt was taken from it, and it was passed to the GPT3.5 model. The task of the model was to generate extensive multiple-choice questions based on the text. The output of the model is a multiple-choice question with options and a correct answer.</p>
#
#
# <p style="font-family: consolas; font-size: 16px;">🔴 To reproduce the collection of the competition's test data, the following steps need to be taken:</p>
#
#    1. <p style="font-family: consolas; font-size: 16px;">Form a list of STEM categories for which the corresponding page will be searched to extract the test from it.</p>
#    2. <p style="font-family: consolas; font-size: 16px;">Randomly select a category or a page related to the corresponding topic or subtopic.</p>
#    3. <p style="font-family: consolas; font-size: 16px;">After selecting the page, extract the text from it.</p>
#    4. <p style="font-family: consolas; font-size: 16px;">Compose a message to the LLM model specifying what needs to be done and provide the extracted text.</p>
#    5. <p style="font-family: consolas; font-size: 16px;">Parse the model's output and perform an automatic check for compliance with the output format.</p>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">🔴 If you are only interested in a dataset of <b>1,000 questions for 250 Wikipedia pages</b>, you can find it by following this <a href="https://www.kaggle.com/datasets/leonidkulyk/wikipedia-stem-1k"><strong>link</strong></a>. Below, the algorithm will be described, and the code will be provided to create or supplement this dataset.</p>

# %% [markdown]
# <a id="2.1"></a>
# ## <div style="box-shadow: rgba(0, 0, 0, 0.18) 0px 2px 4px inset; padding:20px; font-size:24px; font-family: consolas; text-align:center; display:fill; border-radius:15px; color:rgb(67, 66, 66)"> <b> 2.1 Form a list of STEM topics</b></div>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ Each article on Wikipedia has a list of categories to which it belongs.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ Categories are intended to group together pages on similar subjects. They are implemented by a MediaWiki feature that adds any page with a text like [[Category:XYZ]] in its wiki markup to the automated listing that is the category with name XYZ. Categories help readers to find, and navigate around, a subject area, to see pages sorted by title, and to thus find article relationships.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ Categories are normally found at the bottom of an article page. Clicking a category name brings up a category page listing the articles (or other pages) that have been added to that particular category. There may also be a section listing the subcategories of that category. The subcategorization feature makes it possible to organize categories into tree-like structures to aid navigation.</p>
#
# <p style="font-family: consolas; font-size: 16px;">🔴 More information about Wikipedia categories -- <a href="https://en.wikipedia.org/wiki/Help:Category"><strong>link 1</strong></a>, <a href="https://en.wikipedia.org/wiki/Category:Subfields_by_academic_discipline"><strong>link 2</strong></a>.</p>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ Thus, you can create a list of topics on which the page will be searched.</p>

# %%
# probabilities: S -> 0.294; T,E,M -> 0.235
STEM_WEIGHTS = [1.25, 1, 1, 1]

STEM = {
    "S": ["Category:Applied_sciences", "Category:Biotechnology", "Category:Biology", "Category:Natural_history"],
    "T": [
        "Category:Technology_strategy", "Category:Technical_specifications", "Category:Technology_assessment", 
        "Category:Technology_hazards", "Category:Technology_systems", "Category:Hypothetical_technology", 
	
        "Category:Technical_communication", "Category:Technological_comparisons"
    ],
    "E": ["Category:Engineering_disciplines", "Category:Engineering_concepts", "Category:Industrial_equipment", "Category:Manufacturing"],
    "M": ["Category:Fields_of_mathematics", "Category:Physical_sciences"]
}

EXCLUDE_CATEGORIES = set([
    "Category:Technology", "Category:Mathematics", "Category:Works about technology", 
    "Category:Technology evangelism", "Category:Artificial objects", "Category:Fictional physical scientists"
])

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ For example, here is what the list of categories for Category:Subfields by academic discipline looks like.</p>
#
# <p style="text-align:center;"><img src="https://github.com/leo27heady/flask-basics/assets/45982614/fd2b0504-a8fc-44a3-b28a-a528fb4f7910" width="90%" height="90%"></p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ Now let's choose the category Category:Fields of mathematics and see what is inside it.</p>
#
# <p style="text-align:center;"><img src="https://github.com/leo27heady/flask-basics/assets/45982614/23ba4f13-29b9-46b5-b213-31e039f14b5e" width="90%" height="90%"></p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ For the category Category: Fields of mathematics, we have not only subcategories but also pages. This means that we can go deeper into the subcategories or stop at a fairly high level and choose from the available pages.</p>

# %% [markdown]
# <a id="2.2"></a>
# ## <div style="box-shadow: rgba(0, 0, 0, 0.18) 0px 2px 4px inset; padding:20px; font-size:24px; font-family: consolas; text-align:center; display:fill; border-radius:15px; color:rgb(67, 66, 66)"> <b> 2.2 Randomly select a category or a page</b></div>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">🔴 The pipeline for selecting a random article looks as follows:</p>
#
#    1. <p style="font-family: consolas; font-size: 16px;">Randomly choose a STEM topic, i.e., either S or T or E or M.</p>
#    2. <p style="font-family: consolas; font-size: 16px;">Based on the selected STEM topic, choose a random category from its list.</p>
#    3. <p style="font-family: consolas; font-size: 16px;">Take all the subcategories and pages of the chosen category.</p>
#    4. <p style="font-family: consolas; font-size: 16px;">Randomly select a list of subcategories or pages.</p>
#    5. <p style="font-family: consolas; font-size: 16px;">If the selected list is a list of subcategories, then choose a random subcategory and go to Step 3.</p>
#    6. <p style="font-family: consolas; font-size: 16px;">If the selected list is a list of pages, then choose a random page.</p>
#    7. <p style="font-family: consolas; font-size: 16px;">End.</p>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ Python library <a href="https://pypi.org/project/Wikipedia-API/"><strong>Wikipedia-API</strong></a> will be used to interact with Wikipedia.</p>

# %%
def split_category_members(members):
    category_list, page_list= [], []

    for member_name, member_page in members:
        if member_name.startswith('Category') and member_name not in EXCLUDE_CATEGORIES:
            category_list.append((member_name, member_page))
        else:
            page_list.append((member_name, member_page))
    
    return category_list, page_list

def get_wiki_random_page(seed:int, deep_subcategories=True):
    """
    Wikipediaから指定したカテゴリのページをランダムに拾ってくる
    """
    random.seed(seed)
    stem_label, stem_categories = random.choices(list(STEM.items()), weights=STEM_WEIGHTS, k=1)[0]
    category = random.choice(stem_categories)
    print()
    print("category:",category)
    category_page = wiki_wiki.page(category)
    for _ in range(100):
        chosen_list = list(category_page.categorymembers.items())
        if deep_subcategories:
            category_list, page_list = split_category_members(chosen_list)
            chosen_list = []
        else:
            category_list, page_list = [], []

        # 50% change to select category or page list if one of them isn't empty
        # helps to go deeper into subcategories because there're more pages than categories
        if not (category_list or page_list) and not chosen_list:
            continue
        elif not category_list:
            chosen_list = page_list
        elif not page_list:
            chosen_list = category_list
        else:
            chosen_list = random.choice([category_list, page_list])

        # select random page from chosen list
        selected_page_name, selected_page = random.choice(chosen_list)

        if not selected_page_name.startswith("Category"):
            break
        
        category_page = selected_page
    
    return selected_page, stem_label

# %% [markdown]
# <a id="2.3"></a>
# ## <div style="box-shadow: rgba(0, 0, 0, 0.18) 0px 2px 4px inset; padding:20px; font-size:24px; font-family: consolas; text-align:center; display:fill; border-radius:15px; color:rgb(67, 66, 66)"> <b> 2.3 Extract the text from selected page</b></div>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ Text extraction is performed as follows: if a page is long enough (> 6 sentences), the first 7 sentences are taken from the page.</p>

# %%
def get_wiki_text(seen_pages, seed, min_page_length=3, sentences_include=3):
    while True:
        try:
            wiki_page, stem_label = get_wiki_random_page(seed)
            print("seed:",seed)
            seed += 1
        except:
            print("get_wiki_random_page()に失敗")
            seed += 1
            continue

        if wiki_page.pageid in seen_pages:
            print("すでに見たページ")
            seed += 1
            continue

        page_sentences = wiki_page.text.split(". ")
        
        # check is the page is long enought
        if len(page_sentences) >= min_page_length:
            # main information about the topic usualy described within first 3 sentences
            wiki_text = ". ".join(page_sentences[:sentences_include]) + "."
            break
    
    return wiki_text, wiki_page.pageid, wiki_page.title, stem_label

# %% [markdown]
# <a id="2.4"></a>
# ## <div style="box-shadow: rgba(0, 0, 0, 0.18) 0px 2px 4px inset; padding:20px; font-size:24px; font-family: consolas; text-align:center; display:fill; border-radius:15px; color:rgb(67, 66, 66)"> <b> 2.4 Compose a message to the LLM model</b></div>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ The message to the LLM should be precise and clearly convey the essence of the task. It is also good practice to specify the expected output format of the model, as it makes parsing much easier.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ Additionally, it is important to provide any necessary instructions or specifications regarding the desired output. This could include specifying the number of multiple-choice questions to generate, the length or format of the answer options, or any other specific requirements.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ Furthermore, it is recommended to include any relevant context or constraints that should be considered during the text generation process. This could involve providing guidelines on the desired style, tone, or level of complexity for the questions and answers.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ By providing a comprehensive and detailed message to the LLM, the model can better understand and fulfill the requirements, leading to more accurate and tailored results.</p>

# %%
options_set = set(("option_1", "option_2", "option_3", "option_4", "option_5"))
response_keys_set = set(("question", "option_1", "option_2", "option_3", "option_4", "option_5", "answer"))

delimiter = "####"
system_message = f"""
You will be provided with text from Wikipedia, separated by {delimiter} characters. 
From that text, create only one multiple-choice question with 5 options, and express it as a dictionary object. Furthermore, store that dictionary object in a Python list and output it. The dictionary object follows this format:
'question': <question based on the TEXT>
'option_1': <question answer option>
'option_2': <question answer option>
'option_3': <question answer option>
'option_4': <question answer option>
'option_5': <question answer option>
'answer': <answer option key label>
Among the suggested options, the correct one is indicated by assigning the key label ('option_1', 'option_2', 'option_3', 'option_4', 'option_5') to the 'answer' field.
The question, answer, and question options should be broad, challenging, detailed, and based on the given text, and should not be easy.
Please output only the list of objects, without including anything else.
"""

# %%
def get_completion_messages(wiki_text):
    return [  
        {
            'role':'system', 
            'content': system_message
        },    
        {
            'role':'user', 
            'content': f"{delimiter}{wiki_text}{delimiter}"
        },  
    ]

def get_completion_from_messages(
    messages, 
    model="gpt-3.5-turbo", 
    temperature=0.8, 
    max_tokens=3000
):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, 
        max_tokens=max_tokens, 
    )
    print("課金されました")
    return response.choices[0].message["content"]

# %% [markdown]
# <a id="2.5"></a>
# ## <div style="box-shadow: rgba(0, 0, 0, 0.18) 0px 2px 4px inset; padding:20px; font-size:24px; font-family: consolas; text-align:center; display:fill; border-radius:15px; color:rgb(67, 66, 66)"> <b> 2.5 Сombine all elements of the pipeline</b></div>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ In the function gather_multiple_choice_question_dataset, we specify the number of Wikipedia pages for which we want to generate 5 multiple choice question.</p>
#
# <p style="font-family: consolas; font-size: 16px;">⚪ We also set the number of generation attempts per page. If the number of attempts exceeds the specified limit, the generation attempts for that page will be stopped, and another page will be selected.</p>

# %%
import datetime

now = datetime.datetime.now() # 現在時刻の取得
today = now.strftime('%Y_%m_%d') # 現在時刻を年月曜日で表示

# %%
def is_correctly_formatted(mcq) -> bool:
    return all([
        len(el) == len(response_keys_set) and response_keys_set == set(list(el.keys()))
        for el in mcq
    ])

def gather_multiple_choice_question_dataset(
    pages_count: int,
    max_completion_attempts: int = 10,
    seen_pages: list = []
):
    
    attempts_list = []
    multiple_choice_questions = []

    generated_count = 0
    attempts_count = 0
    iterate_count = 0
    while generated_count < pages_count:
        iterate_count += 1
        print("-------------------------------------------------------------")
        print()
        print("generated_count:",generated_count)
        print("attempts_count:",attempts_count)
        print("iterate_count:",iterate_count)
        seed = generated_count+attempts_count+iterate_count
        wiki_text, page_id, page_title, stem_label = get_wiki_text(seen_pages=seen_pages, seed=seed, sentences_include=7)
        print(f"\nStart multiple choice questions generation: page_id={page_id}, page_title={page_title}, stem_label={stem_label}")
        
        messages = get_completion_messages(wiki_text)
        
        while True:
            try:
                chatgpt_response = get_completion_from_messages(messages)
                mcq = eval(chatgpt_response)

                if not isinstance(mcq, list) or not is_correctly_formatted(mcq):
                    raise Exception

                for i in range(len(mcq)):
                    mcq[i]["wiki_text"] = wiki_text
                    mcq[i]["page_id"] = page_id
                    mcq[i]["page_title"] = page_title
                    mcq[i]["stem_label"] = stem_label

                    if mcq[i]["answer"] in options_set:
                        continue
                    else:
                        # index method will raise an error if answer isn't in list
                        answ_indx = [v.lower() for v in mcq[i].values()].index(mcq[i]["answer"].lower())
                        mcq[i]["answer"] = list(mcq[i].keys())[answ_indx]

                multiple_choice_questions += mcq
                with open(f'../input/generate_question_{today}.pickle', 'wb') as f:
                    pickle.dump(multiple_choice_questions, f)
                seen_pages.append(page_id)
                generated_count += 1
                print("Generated count:", generated_count)
                break
            except Exception:
                attempts_count += 1
                #print("Attempts count:", attempts_count)
                attempts_list.append(attempts_count)
                if attempts_count > max_completion_attempts:
                    break
    
    return multiple_choice_questions, seen_pages, attempts_list

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪
# Let's try generating some example multiple choice questions for 2 pages (2 * 5 = 10 questions in total).</p>

# %%
pages_count = 5
max_completion_attempts = 10

wiki_wiki = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'en')

# %% [markdown]
# seed: 2499終わり

# %%
multiple_choice_questions, seen_pages, attempts_list = gather_multiple_choice_question_dataset(
    pages_count, max_completion_attempts
)
# Out:
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 0
# iterate_count: 1
#
# category: Category:Applied_sciences
# seed: 1
#
# Start multiple choice questions generation: page_id=5944849, page_title=Applied economics, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 11
# iterate_count: 2
#
# category: Category:Biotechnology
# seed: 13
#
# Start multiple choice questions generation: page_id=1527537, page_title=Bevacizumab, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 12
# iterate_count: 3
#
# category: Category:Fields_of_mathematics
# seed: 15
#
# Start multiple choice questions generation: page_id=334998, page_title=HP 49/50 series, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 13
# iterate_count: 4
#
# category: Category:Technology_systems
# seed: 17
#
# Start multiple choice questions generation: page_id=24050869, page_title=Inertial navigation system, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 14
# iterate_count: 5
#
# category: Category:Engineering_disciplines
# seed: 19
#
# Start multiple choice questions generation: page_id=53937260, page_title=Power-to-heat, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 15
# iterate_count: 6
#
# category: Category:Natural_history
# seed: 21
#
# Start multiple choice questions generation: page_id=889726, page_title=Insect collecting, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 16
# iterate_count: 7
#
# category: Category:Physical_sciences
# seed: 23
#
# Start multiple choice questions generation: page_id=65462416, page_title=Exoplanet Explorers, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 17
# iterate_count: 8
#
# category: Category:Technology_strategy
# seed: 25
#
# Start multiple choice questions generation: page_id=14723179, page_title=Innovate UK, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 18
# iterate_count: 9
#
# category: Category:Industrial_equipment
# seed: 27
#
# Start multiple choice questions generation: page_id=33970953, page_title=Film blowing machine, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 19
# iterate_count: 10
#
# category: Category:Industrial_equipment
# seed: 29
#
# Start multiple choice questions generation: page_id=24179739, page_title=Cellulose insulating material plant, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 20
# iterate_count: 11
#
# category: Category:Applied_sciences
# seed: 31
#
# Start multiple choice questions generation: page_id=863862, page_title=Artes mechanicae, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 21
# iterate_count: 12
#
# category: Category:Engineering_concepts
# seed: 33
#
# category: Category:Technology_strategy
# seed: 34
#
# Start multiple choice questions generation: page_id=38091302, page_title=Korea Institute for Advancement of Technology, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 22
# iterate_count: 13
#
# category: Category:Engineering_concepts
# seed: 35
#
# Start multiple choice questions generation: page_id=3584524, page_title=Design load, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 23
# iterate_count: 14
#
# category: Category:Engineering_disciplines
# seed: 37
#
# Start multiple choice questions generation: page_id=929750, page_title=Platform supply vessel, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 24
# iterate_count: 15
#
# category: Category:Natural_history
# seed: 39
#
# Start multiple choice questions generation: page_id=1756250, page_title=Tumbes–Chocó–Magdalena, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 25
# iterate_count: 16
#
# category: Category:Technology_hazards
# seed: 41
#
# Start multiple choice questions generation: page_id=18934587, page_title=Radiation monitoring, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 26
# iterate_count: 17
#
# category: Category:Biotechnology
# seed: 43
#
# Start multiple choice questions generation: page_id=65344295, page_title=Human Medicines Regulations 2012, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 27
# iterate_count: 18
#
# category: Category:Natural_history
# seed: 45
#
# Start multiple choice questions generation: page_id=31638583, page_title=Affinity (taxonomy), stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 28
# iterate_count: 19
#
# category: Category:Technical_communication
# seed: 47
#
# Start multiple choice questions generation: page_id=7233280, page_title=Semantic interoperability, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 29
# iterate_count: 20
#
# category: Category:Natural_history
# seed: 49
#
# Start multiple choice questions generation: page_id=27335131, page_title=Caribbean Initiative, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 30
# iterate_count: 21
#
# category: Category:Biotechnology
# seed: 51
#
# Start multiple choice questions generation: page_id=50728706, page_title=Oscillatory baffled reactor, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 31
# iterate_count: 22
#
# category: Category:Engineering_concepts
# seed: 53
#
# Start multiple choice questions generation: page_id=18892315, page_title=Real versus nominal value, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 32
# iterate_count: 23
#
# category: Category:Biotechnology
# seed: 55
#
# Start multiple choice questions generation: page_id=41937628, page_title=Alim Louis Benabid, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 33
# iterate_count: 24
#
# category: Category:Applied_sciences
# seed: 57
#
# Start multiple choice questions generation: page_id=374975, page_title=Worshipful Company of Clockmakers, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 34
# iterate_count: 25
#
# category: Category:Natural_history
# seed: 59
#
# Start multiple choice questions generation: page_id=66156552, page_title=2005 Georgetown flood, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 35
# iterate_count: 26
#
# category: Category:Technology_hazards
# seed: 61
#
# Start multiple choice questions generation: page_id=6852935, page_title=IPv4 address exhaustion, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 36
# iterate_count: 27
#
# category: Category:Technology_systems
# seed: 63
#
# Start multiple choice questions generation: page_id=40626873, page_title=Technological determinism, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 37
# iterate_count: 28
#
# category: Category:Technology_systems
# seed: 65
#
# Start multiple choice questions generation: page_id=58725, page_title=Physical security, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 38
# iterate_count: 29
#
# category: Category:Natural_history
# seed: 67
#
# Start multiple choice questions generation: page_id=48483301, page_title=Bed bug, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 39
# iterate_count: 30
#
# category: Category:Engineering_disciplines
# seed: 69
#
# Start multiple choice questions generation: page_id=1778112, page_title=Front of house, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 40
# iterate_count: 31
#
# category: Category:Technology_strategy
# seed: 71
#
# Start multiple choice questions generation: page_id=56916379, page_title=Process–architecture–optimization model, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 41
# iterate_count: 32
#
# category: Category:Natural_history
# seed: 73
#
# Start multiple choice questions generation: page_id=14310545, page_title=Mannahatta Project, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 42
# iterate_count: 33
#
# category: Category:Technical_communication
# seed: 75
#
# Start multiple choice questions generation: page_id=1224642, page_title=Audience analysis, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 43
# iterate_count: 34
#
# category: Category:Physical_sciences
# seed: 77
#
# Start multiple choice questions generation: page_id=80144, page_title=List of chemists, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 44
# iterate_count: 35
#
# category: Category:Biology
# seed: 79
#
# Start multiple choice questions generation: page_id=35924651, page_title=Bowman–Heidenhain hypothesis, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 45
# iterate_count: 36
#
# category: Category:Technological_comparisons
# seed: 81
#
# Start multiple choice questions generation: page_id=42125403, page_title=Roku, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 46
# iterate_count: 37
#
# category: Category:Technological_comparisons
# seed: 83
#
# category: Category:Engineering_disciplines
# seed: 84
#
# Start multiple choice questions generation: page_id=13856857, page_title=List of engineering branches, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 47
# iterate_count: 38
#
# category: Category:Applied_sciences
# seed: 85
#
# Start multiple choice questions generation: page_id=5236980, page_title=Criminal investigation, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 48
# iterate_count: 39
#
# category: Category:Biotechnology
# seed: 87
#
# Start multiple choice questions generation: page_id=32069686, page_title=Elsevier Biobase, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 49
# iterate_count: 40
#
# category: Category:Biology
# seed: 89
#
# Start multiple choice questions generation: page_id=35531280, page_title=Olavius algarvensis, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 50
# iterate_count: 41
#
# category: Category:Biotechnology
# seed: 91
#
# category: Category:Technology_systems
# seed: 92
#
# Start multiple choice questions generation: page_id=12205222, page_title=Coherence time (communications systems), stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 51
# iterate_count: 42
#
# category: Category:Physical_sciences
# seed: 93
#
# Start multiple choice questions generation: page_id=23638, page_title=Outline of physical science, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 52
# iterate_count: 43
#
# category: Category:Engineering_concepts
# seed: 95
#
# Start multiple choice questions generation: page_id=15498298, page_title=Allowable Strength Design, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 53
# iterate_count: 44
#
# category: Category:Biology
# seed: 97
#
# category: Category:Technology_strategy
# seed: 98
#
# Start multiple choice questions generation: page_id=15763075, page_title=Technology intelligence, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 54
# iterate_count: 45
#
# category: Category:Technology_hazards
# seed: 99
#
# Start multiple choice questions generation: page_id=43591208, page_title=Instrumental convergence, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 55
# iterate_count: 46
#
# category: Category:Engineering_concepts
# seed: 101
#
# Start multiple choice questions generation: page_id=1161552, page_title=Parts stress modelling, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 56
# iterate_count: 47
#
# category: Category:Physical_sciences
# seed: 103
#
# Start multiple choice questions generation: page_id=7085992, page_title=Interplanetary magnetic field, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 57
# iterate_count: 48
#
# category: Category:Physical_sciences
# seed: 105
#
# category: Category:Manufacturing
# seed: 106
#
# Start multiple choice questions generation: page_id=42625971, page_title=Plate column, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 58
# iterate_count: 49
#
# category: Category:Natural_history
# seed: 107
#
# category: Category:Applied_sciences
# seed: 108
#
# Start multiple choice questions generation: page_id=26740386, page_title=Heritage science, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 59
# iterate_count: 50
#
# category: Category:Natural_history
# seed: 109
#
# Start multiple choice questions generation: page_id=38973180, page_title=List of parson-naturalists, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 60
# iterate_count: 51
#
# category: Category:Fields_of_mathematics
# seed: 111
#
# category: Category:Technology_systems
# seed: 112
#
# Start multiple choice questions generation: page_id=41771, page_title=System integrity, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 61
# iterate_count: 52
#
# category: Category:Biology
# seed: 113
#
# Start multiple choice questions generation: page_id=41442761, page_title=Experimental biology, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 62
# iterate_count: 53
#
# category: Category:Fields_of_mathematics
# seed: 115
#
# Start multiple choice questions generation: page_id=58232142, page_title=The monkey and the coconuts, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 63
# iterate_count: 54
#
# category: Category:Biotechnology
# seed: 117
#
# Start multiple choice questions generation: page_id=35917093, page_title=List of sequenced animal genomes, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 64
# iterate_count: 55
#
# category: Category:Fields_of_mathematics
# seed: 119
#
# Start multiple choice questions generation: page_id=53252845, page_title=Glossary of calculus, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 65
# iterate_count: 56
#
# category: Category:Natural_history
# seed: 121
#
# category: Category:Technology_systems
# seed: 122
#
# Start multiple choice questions generation: page_id=6591457, page_title=Mamiya C220, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 66
# iterate_count: 57
#
# category: Category:Applied_sciences
# seed: 123
#
# Start multiple choice questions generation: page_id=26740386, page_title=Heritage science, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 67
# iterate_count: 58
#
# category: Category:Fields_of_mathematics
# seed: 125
#
# Start multiple choice questions generation: page_id=3008091, page_title=Mathematics Subject Classification, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 68
# iterate_count: 59
#
# category: Category:Applied_sciences
# seed: 127
#
# Start multiple choice questions generation: page_id=4228914, page_title=Lydia Fairchild, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 69
# iterate_count: 60
#
# category: Category:Industrial_equipment
# seed: 129
#
# Start multiple choice questions generation: page_id=36717714, page_title=Miner's apron, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 70
# iterate_count: 61
#
# category: Category:Technical_specifications
# seed: 131
#
# Start multiple choice questions generation: page_id=11234940, page_title=ISO/TC 37, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 71
# iterate_count: 62
#
# category: Category:Technological_comparisons
# seed: 133
#
# category: Category:Technology_hazards
# seed: 134
#
# Start multiple choice questions generation: page_id=20541638, page_title=Tester-driven development, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 72
# iterate_count: 63
#
# category: Category:Industrial_equipment
# seed: 135
#
# Start multiple choice questions generation: page_id=21522001, page_title=Hydromill trench cutter, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 73
# iterate_count: 64
#
# category: Category:Natural_history
# seed: 137
#
# Start multiple choice questions generation: page_id=665333, page_title=Cymdeithas Edward Llwyd, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 74
# iterate_count: 65
#
# category: Category:Biology
# seed: 139
#
# Start multiple choice questions generation: page_id=2639400, page_title=Blue ice (aviation), stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 75
# iterate_count: 66
#
# category: Category:Technology_strategy
# seed: 141
#
# Start multiple choice questions generation: page_id=31793449, page_title=Transition management (governance), stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 76
# iterate_count: 67
#
# category: Category:Fields_of_mathematics
# seed: 143
#
# Start multiple choice questions generation: page_id=45311707, page_title=Servomechanism, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 77
# iterate_count: 68
#
# category: Category:Physical_sciences
# seed: 145
#
# Start multiple choice questions generation: page_id=614515, page_title=Ship model basin, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 78
# iterate_count: 69
#
# category: Category:Engineering_concepts
# seed: 147
#
# Start multiple choice questions generation: page_id=36726976, page_title=Operational availability, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 79
# iterate_count: 70
#
# category: Category:Biology
# seed: 149
#
# Start multiple choice questions generation: page_id=3108062, page_title=Bioelectromagnetics, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 80
# iterate_count: 71
#
# category: Category:Engineering_concepts
# seed: 151
#
# Start multiple choice questions generation: page_id=14041062, page_title=Function–means tree, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 81
# iterate_count: 72
#
# category: Category:Fields_of_mathematics
# seed: 153
#
# Start multiple choice questions generation: page_id=19727024, page_title=Rational number, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 82
# iterate_count: 73
#
# category: Category:Industrial_equipment
# seed: 155
#
# Start multiple choice questions generation: page_id=42307071, page_title=Starch mogul, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 83
# iterate_count: 74
#
# category: Category:Engineering_concepts
# seed: 157
#
# Start multiple choice questions generation: page_id=4219501, page_title=Andon (manufacturing), stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 84
# iterate_count: 75
#
# category: Category:Technological_comparisons
# seed: 159
#
# category: Category:Biology
# seed: 160
#
# Start multiple choice questions generation: page_id=13478480, page_title=Biological exponential growth, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 85
# iterate_count: 76
#
# category: Category:Technology_assessment
# seed: 161
#
# Start multiple choice questions generation: page_id=73365448, page_title=Internet of Musical Things, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 86
# iterate_count: 77
#
# category: Category:Manufacturing
# seed: 163
#
# Start multiple choice questions generation: page_id=50265507, page_title=Heat transfer through fins, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 87
# iterate_count: 78
#
# category: Category:Natural_history
# seed: 165
#
# Start multiple choice questions generation: page_id=1195135, page_title=Oliver Rackham, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 88
# iterate_count: 79
#
# category: Category:Applied_sciences
# seed: 167
#
# Start multiple choice questions generation: page_id=72231021, page_title=SN Applied Sciences, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 89
# iterate_count: 80
#
# category: Category:Biotechnology
# seed: 169
#
# Start multiple choice questions generation: page_id=61384892, page_title=Spectral imaging (radiography), stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 90
# iterate_count: 81
#
# category: Category:Physical_sciences
# seed: 171
#
# Start multiple choice questions generation: page_id=23638, page_title=Outline of physical science, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 91
# iterate_count: 82
#
# category: Category:Hypothetical_technology
# seed: 173
#
# Start multiple choice questions generation: page_id=57561917, page_title=Trancitor, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 92
# iterate_count: 83
#
# category: Category:Technology_strategy
# seed: 175
#
# Start multiple choice questions generation: page_id=2279892, page_title=Wirth's law, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 93
# iterate_count: 84
#
# category: Category:Physical_sciences
# seed: 177
#
# Start multiple choice questions generation: page_id=64208794, page_title=Macroscope (science concept), stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 94
# iterate_count: 85
#
# category: Category:Fields_of_mathematics
# seed: 179
#
# Start multiple choice questions generation: page_id=13034946, page_title=Modified Dietz method, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 95
# iterate_count: 86
#
# category: Category:Engineering_disciplines
# seed: 181
#
# Start multiple choice questions generation: page_id=1182291, page_title=Design engineer, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 96
# iterate_count: 87
#
# category: Category:Applied_sciences
# seed: 183
#
# Start multiple choice questions generation: page_id=93827, page_title=Human nutrition, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 97
# iterate_count: 88
#
# category: Category:Fields_of_mathematics
# seed: 185
#
# Start multiple choice questions generation: page_id=32592462, page_title=Series multisection, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 98
# iterate_count: 89
#
# category: Category:Technological_comparisons
# seed: 187
#
# Start multiple choice questions generation: page_id=47143780, page_title=Comparison of programming languages (functional programming), stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 99
# iterate_count: 90
#
# category: Category:Technology_systems
# seed: 189
#
# Start multiple choice questions generation: page_id=69461111, page_title=TNet, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 100
# iterate_count: 91
#
# category: Category:Engineering_concepts
# seed: 191
#
# Start multiple choice questions generation: page_id=22936371, page_title=Tolerance coning, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 101
# iterate_count: 92
#
# category: Category:Engineering_concepts
# seed: 193
#
# Start multiple choice questions generation: page_id=185529, page_title=Scalability, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 102
# iterate_count: 93
#
# category: Category:Engineering_disciplines
# seed: 195
#
# Start multiple choice questions generation: page_id=515992, page_title=Undefined behavior, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 103
# iterate_count: 94
#
# category: Category:Engineering_concepts
# seed: 197
#
# Start multiple choice questions generation: page_id=35454200, page_title=Kanban board, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 104
# iterate_count: 95
#
# category: Category:Technical_communication
# seed: 199
#
# Start multiple choice questions generation: page_id=18934904, page_title=Technical standard, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 105
# iterate_count: 96
#
# category: Category:Biology
# seed: 201
#
# category: Category:Manufacturing
# seed: 202
#
# category: Category:Natural_history
# seed: 203
#
# category: Category:Technical_specifications
# seed: 204
#
# Start multiple choice questions generation: page_id=74007634, page_title=Operational design domain, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 106
# iterate_count: 97
#
# category: Category:Natural_history
# seed: 203
#
# category: Category:Technical_specifications
# seed: 204
#
# Start multiple choice questions generation: page_id=74007634, page_title=Operational design domain, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 107
# iterate_count: 98
#
# category: Category:Technical_specifications
# seed: 205
#
# Start multiple choice questions generation: page_id=3452561, page_title=OpenDocument technical specification, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 108
# iterate_count: 99
#
# category: Category:Technology_hazards
# seed: 207
#
# Start multiple choice questions generation: page_id=20096370, page_title=Magic string, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 109
# iterate_count: 100
#
# category: Category:Engineering_disciplines
# seed: 209
#
# Start multiple choice questions generation: page_id=36680, page_title=Combinatorial chemistry, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 110
# iterate_count: 101
#
# category: Category:Engineering_concepts
# seed: 211
#
# Start multiple choice questions generation: page_id=4594861, page_title=Water–cement ratio, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 111
# iterate_count: 102
#
# category: Category:Biotechnology
# seed: 213
#
# Start multiple choice questions generation: page_id=646842, page_title=Agrobacterium, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 112
# iterate_count: 103
#
# category: Category:Biology
# seed: 215
#
# Start multiple choice questions generation: page_id=61640184, page_title=School of Clinical Medicine, University of Cambridge, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 113
# iterate_count: 104
#
# category: Category:Fields_of_mathematics
# seed: 217
#
# Start multiple choice questions generation: page_id=5161105, page_title=Brahmagupta's identity, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 114
# iterate_count: 105
#
# category: Category:Industrial_equipment
# seed: 219
#
# Start multiple choice questions generation: page_id=38345915, page_title=Micrometer adjustment nut, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 115
# iterate_count: 106
#
# category: Category:Applied_sciences
# seed: 221
#
# Start multiple choice questions generation: page_id=26740386, page_title=Heritage science, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 116
# iterate_count: 107
#
# category: Category:Technological_comparisons
# seed: 223
#
# category: Category:Biotechnology
# seed: 224
#
# Start multiple choice questions generation: page_id=72152911, page_title=Biofabrication, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 117
# iterate_count: 108
#
# category: Category:Engineering_concepts
# seed: 225
#
# Start multiple choice questions generation: page_id=221530, page_title=De Rham cohomology, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 118
# iterate_count: 109
#
# category: Category:Hypothetical_technology
# seed: 227
#
# Start multiple choice questions generation: page_id=36958784, page_title=Incredible utility, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 119
# iterate_count: 110
#
# category: Category:Technology_hazards
# seed: 229
#
# Start multiple choice questions generation: page_id=1205325, page_title=High voltage, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 120
# iterate_count: 111
#
# category: Category:Fields_of_mathematics
# seed: 231
#
# Start multiple choice questions generation: page_id=502205, page_title=Diophantine geometry, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 121
# iterate_count: 112
#
# category: Category:Engineering_concepts
# seed: 233
#
# category: Category:Technology_strategy
# seed: 234
#
# Start multiple choice questions generation: page_id=15286988, page_title=Tick–tock model, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 122
# iterate_count: 113
#
# category: Category:Technology_strategy
# seed: 235
#
# Start multiple choice questions generation: page_id=38091302, page_title=Korea Institute for Advancement of Technology, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 123
# iterate_count: 114
#
# category: Category:Engineering_concepts
# seed: 237
#
# Start multiple choice questions generation: page_id=18938636, page_title=Decompiler, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 124
# iterate_count: 115
#
# category: Category:Biotechnology
# seed: 239
#
# Start multiple choice questions generation: page_id=45784, page_title=Biomimetics, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 125
# iterate_count: 116
#
# category: Category:Engineering_disciplines
# seed: 241
#
# Start multiple choice questions generation: page_id=12743856, page_title=Polymer engineering, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 126
# iterate_count: 117
#
# category: Category:Physical_sciences
# seed: 243
#
# Start multiple choice questions generation: page_id=23638, page_title=Outline of physical science, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 127
# iterate_count: 118
#
# category: Category:Natural_history
# seed: 245
#
# Start multiple choice questions generation: page_id=44855053, page_title=Le Règne Animal, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 128
# iterate_count: 119
#
# category: Category:Technology_strategy
# seed: 247
#
# Start multiple choice questions generation: page_id=15763075, page_title=Technology intelligence, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 129
# iterate_count: 120
#
# category: Category:Biology
# seed: 249
#
# Start multiple choice questions generation: page_id=20433613, page_title=Universality–diversity paradigm, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 130
# iterate_count: 121
#
# category: Category:Technical_communication
# seed: 251
#
# Start multiple choice questions generation: page_id=3442409, page_title=Grey literature, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 131
# iterate_count: 122
#
# category: Category:Manufacturing
# seed: 253
#
# Start multiple choice questions generation: page_id=49261105, page_title=Directed assembly of micro- and nano-structures, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 132
# iterate_count: 123
#
# category: Category:Applied_sciences
# seed: 255
#
# Start multiple choice questions generation: page_id=912551, page_title=Archaeological science, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 133
# iterate_count: 124
#
# category: Category:Technical_specifications
# seed: 257
#
# Start multiple choice questions generation: page_id=14934, page_title=International Organization for Standardization, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 134
# iterate_count: 125
#
# category: Category:Applied_sciences
# seed: 259
#
# Start multiple choice questions generation: page_id=63287494, page_title=Jim Browning (YouTuber), stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 135
# iterate_count: 126
#
# category: Category:Technology_strategy
# seed: 261
#
# Start multiple choice questions generation: page_id=39395954, page_title=Hyperscale computing, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 136
# iterate_count: 127
#
# category: Category:Manufacturing
# seed: 263
#
# Start multiple choice questions generation: page_id=52062473, page_title=Spinning bee, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 137
# iterate_count: 128
#
# category: Category:Physical_sciences
# seed: 265
#
# Start multiple choice questions generation: page_id=31071816, page_title=Geoprofessions, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 138
# iterate_count: 129
#
# category: Category:Natural_history
# seed: 267
#
# Start multiple choice questions generation: page_id=39270850, page_title=Alfred Russel Wallace centenary, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 139
# iterate_count: 130
#
# category: Category:Applied_sciences
# seed: 269
#
# Start multiple choice questions generation: page_id=5236980, page_title=Criminal investigation, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 140
# iterate_count: 131
#
# category: Category:Hypothetical_technology
# seed: 271
#
# Start multiple choice questions generation: page_id=37852, page_title=Fusion rocket, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 141
# iterate_count: 132
#
# category: Category:Biotechnology
# seed: 273
#
# Start multiple choice questions generation: page_id=57313623, page_title=Spatial transcriptomics, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 142
# iterate_count: 133
#
# category: Category:Engineering_disciplines
# seed: 275
#
# Start multiple choice questions generation: page_id=19528, page_title=Mechanical engineering, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 143
# iterate_count: 134
#
# category: Category:Fields_of_mathematics
# seed: 277
#
# Start multiple choice questions generation: page_id=3397404, page_title=Thomae's function, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 144
# iterate_count: 135
#
# category: Category:Technology_strategy
# seed: 279
#
# Start multiple choice questions generation: page_id=31793449, page_title=Transition management (governance), stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 145
# iterate_count: 136
#
# category: Category:Biology
# seed: 281
#
# Start multiple choice questions generation: page_id=46241024, page_title=World Engineering Anthropometry Resource, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 146
# iterate_count: 137
#
# category: Category:Engineering_concepts
# seed: 283
#
# Start multiple choice questions generation: page_id=2554772, page_title=Overhead (engineering), stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 147
# iterate_count: 138
#
# category: Category:Manufacturing
# seed: 285
#
# Start multiple choice questions generation: page_id=42541439, page_title=Closed-loop manufacturing, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 148
# iterate_count: 139
#
# category: Category:Industrial_equipment
# seed: 287
#
# Start multiple choice questions generation: page_id=23875819, page_title=Coiled tubing umbilical, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 149
# iterate_count: 140
#
# category: Category:Physical_sciences
# seed: 289
#
# Start multiple choice questions generation: page_id=50650, page_title=Astronomy, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 150
# iterate_count: 141
#
# category: Category:Engineering_disciplines
# seed: 291
#
# Start multiple choice questions generation: page_id=37207, page_title=Nuclear engineering, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 151
# iterate_count: 142
#
# category: Category:Technical_specifications
# seed: 293
#
# Start multiple choice questions generation: page_id=47111027, page_title=Implementation Rule, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 152
# iterate_count: 143
#
# category: Category:Physical_sciences
# seed: 295
#
# Start multiple choice questions generation: page_id=33615960, page_title=Comparison of chemistry and physics, stem_label=M
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 153
# iterate_count: 144
#
# category: Category:Technical_communication
# seed: 297
#
# category: Category:Biotechnology
# seed: 298
#
# Start multiple choice questions generation: page_id=233253, page_title=Umbilical cord, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 154
# iterate_count: 145
#
# category: Category:Technology_hazards
# seed: 299
#
# Start multiple choice questions generation: page_id=303218, page_title=Rear-end collision, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 155
# iterate_count: 146
#
# category: Category:Technological_comparisons
# seed: 301
#
# category: Category:Physical_sciences
# seed: 302
#
# category: Category:Biotechnology
# seed: 303
#
# Start multiple choice questions generation: page_id=26188309, page_title=Generator Rex, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 156
# iterate_count: 147
#
# category: Category:Biotechnology
# seed: 303
#
# Start multiple choice questions generation: page_id=26188309, page_title=Generator Rex, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 157
# iterate_count: 148
#
# category: Category:Natural_history
# seed: 305
#
# Start multiple choice questions generation: page_id=5318004, page_title=Kunstformen der Natur, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 158
# iterate_count: 149
#
# category: Category:Industrial_equipment
# seed: 307
#
# Start multiple choice questions generation: page_id=10980696, page_title=Separator (oil production), stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 159
# iterate_count: 150
#
# category: Category:Applied_sciences
# seed: 309
#
# Start multiple choice questions generation: page_id=25582908, page_title=Agastache foeniculum, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 160
# iterate_count: 151
#
# category: Category:Physical_sciences
# seed: 311
#
# category: Category:Manufacturing
# seed: 312
#
# Start multiple choice questions generation: page_id=74474403, page_title=Inductotherm Group, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 161
# iterate_count: 152
#
# category: Category:Manufacturing
# seed: 313
#
# Start multiple choice questions generation: page_id=18159068, page_title=Advanced manufacturing, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 162
# iterate_count: 153
#
# category: Category:Technical_communication
# seed: 315
#
# Start multiple choice questions generation: page_id=21612644, page_title=AgcXML, stem_label=T
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 163
# iterate_count: 154
#
# category: Category:Technical_communication
# seed: 317
#
# category: Category:Engineering_disciplines
# seed: 318
#
# Start multiple choice questions generation: page_id=36203752, page_title=Frugal innovation, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 164
# iterate_count: 155
#
# category: Category:Applied_sciences
# seed: 319
#
# Start multiple choice questions generation: page_id=631934, page_title=Applied anthropology, stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 165
# iterate_count: 156
#
# category: Category:Biotechnology
# seed: 321
#
# Start multiple choice questions generation: page_id=13515972, page_title=Nick (DNA), stem_label=S
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 166
# iterate_count: 157
#
# category: Category:Engineering_disciplines
# seed: 323
#
# Start multiple choice questions generation: page_id=25929756, page_title=Automated mineralogy, stem_label=E
# -------------------------------------------------------------
#
# generated_count: 0
# attempts_count: 167
# iterate_count: 158
#
# category: Category:Engineering_concepts
# seed: 325
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb セル 55 line 1
# ----> <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=0'>1</a> multiple_choice_questions, seen_pages, attempts_list = gather_multiple_choice_question_dataset(
#       <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=1'>2</a>     pages_count, max_completion_attempts
#       <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=2'>3</a> )
#
# /Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb セル 55 line 2
#      <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=24'>25</a> print("iterate_count:",iterate_count)
#      <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=25'>26</a> seed = generated_count+attempts_count+iterate_count
# ---> <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=26'>27</a> wiki_text, page_id, page_title, stem_label = get_wiki_text(seen_pages=seen_pages, seed=seed, sentences_include=7)
#      <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=27'>28</a> print(f"\nStart multiple choice questions generation: page_id={page_id}, page_title={page_title}, stem_label={stem_label}")
#      <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=29'>30</a> messages = get_completion_messages(wiki_text)
#
# /Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb セル 55 line 1
#      <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=13'>14</a>     seed += 1
#      <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=14'>15</a>     continue
# ---> <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=16'>17</a> page_sentences = wiki_page.text.split(". ")
#      <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=18'>19</a> # check is the page is long enought
#      <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=19'>20</a> if len(page_sentences) >= min_page_length:
#      <a href='vscode-notebook-cell:/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/code_analysis/eda-data-gathering-llm-se-wiki-stem-1k-ds.ipynb#Y105sZmlsZQ%3D%3D?line=20'>21</a>     # main information about the topic usualy described within first 3 sentences
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:976, in WikipediaPage.text(self)
#     969 @property
#     970 def text(self) -> str:
#     971     """
#     972     Returns text of the current page.
#     973
#     974     :return: text of the current page
#     975     """
# --> 976     txt = self.summary
#     977     if len(txt) > 0:
#     978         txt += "\n\n"
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:921, in WikipediaPage.summary(self)
#     915 """
#     916 Returns summary of the current page.
#     917
#     918 :return: summary
#     919 """
#     920 if not self._called["extracts"]:
# --> 921     self._fetch("extracts")
#     922 return self._summary
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:1065, in WikipediaPage._fetch(self, call)
#    1063 def _fetch(self, call) -> "WikipediaPage":
#    1064     """Fetches some data?."""
# -> 1065     getattr(self.wiki, call)(self)
#    1066     self._called[call] = True
#    1067     return self
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:297, in Wikipedia.extracts(self, page, **kwargs)
#     294 used_params = kwargs
#     295 used_params.update(params)
# --> 297 raw = self._query(page, used_params)
#     298 self._common_attributes(raw["query"], page)
#     299 pages = raw["query"]["pages"]
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:529, in Wikipedia._query(self, page, params)
#     527 params["format"] = "json"
#     528 params["redirects"] = 1
# --> 529 r = self._session.get(base_url, params=params, **self._request_kwargs)
#     530 return r.json()
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/python/kaggle/LLM_Science_Exam/venv/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ Let's examine the output provided by the GPT3.5-turbo model.</p>

# %%
with open('/Users/koshidatatsuo/python/kaggle/LLM_Science_Exam/input/generate_question_2023_09_07.pickle', 'rb') as f:
    multiple_choice_questions = pickle.load(f)

# %%
df_mcq = pd.DataFrame.from_records(multiple_choice_questions)
table = itables.show(df_mcq)
table
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="4353a35b-c33f-40b3-bbb4-61b5b4c5701a" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>question</th>
#       <th>option_1</th>
#       <th>option_2</th>
#       <th>option_3</th>
#       <th>option_4</th>
#       <th>option_5</th>
#       <th>answer</th>
#       <th>wiki_text</th>
#       <th>page_id</th>
#       <th>page_title</th>
#       <th>stem_label</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [["What is the purpose of applied economics?", "To enhance the quality of business practices and national policy making", "To study economic theory and econometrics", "To address practical issues in a range of fields", "To engage in empirical estimation using econometrics", "To analyze historical analogy and case studies", "option_1", "Applied economics is the study as regards the application of economic theory and econometrics in specific settings. As one of the two sets of fields of economics (the other set being the core), it is typically characterized by the application of the core, i.e. economic theory and econometrics to address practical issues in a range of fields including  demographic economics, labour economics, business economics, industrial organization, agricultural economics, development economics, education economics, engineering economics, financial economics, health economics, monetary economics, public economics, and economic history. From the perspective of economic development, the purpose of applied economics is to enhance the quality of business practices and national policy making.The process often involves a reduction in the level of abstraction of this core theory. There are a variety of approaches including not only empirical estimation using econometrics, input-output analysis or simulations but also case studies, historical analogy and so-called common sense or the \"vernacular\".  This range of approaches is indicative of what Roger Backhouse and Jeff Biddle argue is the ambiguous nature of the concept of applied economics. It is a concept with multiple meanings.", 5944849, "Applied economics", "S"], ["What is the purpose of using photobiotin as a biochemical tool?", "To label proteins, DNA, RNA probes, or other molecules", "To degrade DNA and RNA", "To activate enzymes", "To prepare calmodulin derivatives", "To characterize biotin", "option_1", "Photobiotin is a derivative of biotin used as a biochemical tool.  It is composed of a biotin group, a linker group, and a photoactivatable aryl azide group.\\nThe photoactivatable group provides nonspecific labeling of proteins, DNA and RNA probes or other molecules. Biotinylation of DNA and RNA with photoactivatable biotin is easier and less expensive than enzymatic methods since the DNA and RNA does not degrade.  Photobiotin is most effectively activated by light at 260-475 nm.\\n\\nReferences\\nBillingsley, M. and J. Polli.  \u201cPreparation, characterization and biological properties of biotinylated derivatives of calmodulin.\u201d Biochem J.", 10977940, "Photobiotin", "S"], ["Which conference is considered to be one of the top conferences in computer vision?", "ICCV", "CVPR", "ECCV", "IEEE", "Helmholtz Prize", "option_1", "The International Conference on Computer Vision (ICCV) is a research conference sponsored by the Institute of Electrical and Electronics Engineers (IEEE) held every other year. It is considered to be one of the top conferences in computer vision, alongside CVPR and ECCV,\\nand it is held on years in which ECCV is not.\\nThe conference is usually spread over four to five days. Typically, experts in the focus areas give tutorial talks on the first day, then the technical sessions (and poster sessions in parallel) follow. Recent conferences have also had an increasing number of focused workshops and a commercial exhibition.\\n\\nAwards\\nAzriel Rosenfeld Lifetime Achievement Award\\nThe Azriel Rosenfeld Award, or Azriel Rosenfeld Lifetime Achievement Award, recognizes researchers who have made significant contributions to the field of computer vision over their careers. It is named in memory of computer scientist and mathematician Azriel Rosenfeld. The following people have received this award:\\n\\nHelmholtz Prize\\nThe ICCV Helmholtz Prize, known as the Test of Time Award before 2013, is awarded every other year at the ICCV, recognizing ICCV papers from ten or more years earlier that had a significant impact on co ...

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ To convert <code>df_mcq</code> to competition format - use this code snippet:</p>

# %%
def conver_df_to_compet_format(df):
    df_compet = df.copy(deep=True)
    df_compet.insert(0, "id", list(range(len(df_compet))))
    df_compet.rename(
        columns = {
            'question': 'prompt', 
            'option_1': 'A', 
            'option_2': 'B', 
            'option_3': 'C', 
            'option_4': 'D', 
            'option_5': 'E'
        }, 
        inplace = True
    )

    answer_subjects = {
        'option_1': 'A', 
        'option_2': 'B', 
        'option_3': 'C', 
        'option_4': 'D', 
        'option_5': 'E'
    }
    df_compet["answer"] = df_compet["answer"].map(answer_subjects)
    df_compet = df_compet.drop(columns=["wiki_text", "page_id", "page_title", "stem_label"])

    return df_compet

# %%
df_compet = conver_df_to_compet_format(df_mcq)
df_compet.to_csv(f"../input/stem_dataset_{today}.csv", index=False)

# %% [markdown]
# <a id="3"></a>
# # <div style="box-shadow: rgba(0, 0, 0, 0.16) 0px 1px 4px inset, rgb(51, 51, 51) 0px 0px 0px 3px inset; padding:20px; font-size:32px; font-family: consolas; text-align:center; display:fill; border-radius:15px;  color:rgb(34, 34, 34);"> <b> 3. Data gathering enhancements</b></div>

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">⚪ The most prioritized areas for improving the data collector are:</p>
#
# - <p style="font-family: consolas; font-size: 16px;">Enhancing the output structure of the LLM model and the overall prompt.</p>
# - <p style="font-family: consolas; font-size: 16px;">More accurate selection of STEM categories.</p>
# - <p style="font-family: consolas; font-size: 16px;">Filtering out simple questions.</p>
# - <p style="font-family: consolas; font-size: 16px;">Improving the algorithm for randomization to delve deeper into subcategories.</p>
# - <p style="font-family: consolas; font-size: 16px;">Randomizing STEM topics with a emphasis on "S".</p>
# - <p style="font-family: consolas; font-size: 16px;">"Smarter" selection of excerpts from pages.</p>
# - <p style="font-family: consolas; font-size: 16px;">Check the length of the requested prompt tokens and reduce it if needed.</p>
# - <p style="font-family: consolas; font-size: 16px;">Try another open source LLM for multiple choice question text completion.</p>

# %% [markdown]
# # <div style="box-shadow: rgba(240, 46, 170, 0.4) -5px 5px inset, rgba(240, 46, 170, 0.3) -10px 10px inset, rgba(240, 46, 170, 0.2) -15px 15px inset, rgba(240, 46, 170, 0.1) -20px 20px inset, rgba(240, 46, 170, 0.05) -25px 25px inset; padding:20px; font-size:30px; font-family: consolas; display:fill; border-radius:15px; color: rgba(240, 46, 170, 0.7)"> <b> ༼⁠ ⁠つ⁠ ⁠◕⁠‿⁠◕⁠ ⁠༽⁠つ Thank You!</b></div>
#
# <p style="font-family:verdana; color:rgb(34, 34, 34); font-family: consolas; font-size: 16px;"> 💌 Thank you for taking the time to read through my notebook. I hope you found it interesting and informative. If you have any feedback or suggestions for improvement, please don't hesitate to let me know in the comments. <br><br> 🚀 If you liked this notebook, please consider upvoting it so that others can discover it too. Your support means a lot to me, and it helps to motivate me to create more content in the future. <br><br> ❤️ Once again, thank you for your support, and I hope to see you again soon!</p>
